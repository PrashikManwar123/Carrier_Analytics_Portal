# %%
import pandas as pd

df = pd.read_csv('HR_comma_sep.csv').drop(columns=['left'])
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# min               96.000000            2.000000       0.000000
# 25%              156.000000            3.000000       0.000000
# ...

# %%
df = df.drop(columns=['last_evaluation','number_project'])
df
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  \
# 0                    0.38                   157                   3
# 1                    0.80                   262                   6
# 2                    0.11                   272                   4
# 3                    0.72                   223                   5
# 4                    0.37                   159                   3
# ...                   ...                   ...                 ...
# 14994                0.40                   151                   3
# 14995                0.37                   160                   3
# 14996                0.37                   143                   3
# 14997                0.11                   280                   4
# 14998                0.37                   158                   3
#
#        Work_accident  promotion_last_5years Department  salary
# 0                  0                      0      sales     low
# ...

# %%
print(df['salary'].value_counts())
print(df['Department'].value_counts())
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Department'] = le.fit_transform(df['Department'])
df['salary'] = le.fit_transform(df['salary'])

# %%
df
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  \
# 0                    0.38                   157                   3
# 1                    0.80                   262                   6
# 2                    0.11                   272                   4
# 3                    0.72                   223                   5
# 4                    0.37                   159                   3
# ...                   ...                   ...                 ...
# 14994                0.40                   151                   3
# 14995                0.37                   160                   3
# 14996                0.37                   143                   3
# 14997                0.11                   280                   4
# 14998                0.37                   158                   3
#
#        Work_accident  promotion_last_5years  Department  salary
# 0                  0                      0           7       1
# ...

# %%
print(df['salary'].value_counts())
print(df['Department'].value_counts())
# Out:
# salary
# 1    7316
# 2    6446
# 0    1237
# Name: count, dtype: int64
# Department
# 7    4140
# 9    2720
# 8    2229
# 0    1227
# 6     902
# 5     858
# 1     787
# 2     767
# 3     739
# 4     630
# Name: count, dtype: int64

# %% [raw]
# Department: (jobrole)
#
# sales          7
# technical      9
# support        8
# IT             0
# product_mng    6
# marketing      5
# RandD          1
# accounting     2
# hr             3
# management     4

# %% [raw]
# salary:
#
# low       1
# medium    2
# high      0

# %%
X = df.drop(columns=['satisfaction_level'])
y = df[['satisfaction_level']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_test,y_test)
# Out:
# C:\Users\prshi\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0.6447    , 0.78514   , 0.393     , ..., 0.64346667, 0.6632    ,
#        0.78826333])

# %%
model.score(X_test, y_test)
# Out:
# 0.8375271708494582

# %%
#saving the trained model
import pickle
filename = "sat_pred.sav"
pickle.dump(model, open(filename,"wb"))

#loading the saved model
loaded_model = pickle.load(open('sat_pred.sav', 'rb'))
